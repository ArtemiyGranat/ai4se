# %%
from toxic_clf.data import prepare
from toxic_clf.models import classifier

# %%
ds = prepare("prepared-dataset/code-review-dataset-full.xlsx")
ds
# Out:
# 100%|██████████| 6/6 [00:31<00:00,  5.26s/it]
# Dataset({
#     features: ['message', 'is_toxic'],
#     num_rows: 12904
# })

# %%
classifier(ds, "logistic_regression")
# Out:
# 10it [00:02,  4.52it/s]
# Mean Accuracy: 0.8534316208529383
# Mean Standard Deviation: 0.008911632107276425
# Accuracy: 0.8834
# F1 Score: 0.6252
# Precision: 0.8625
# Recall: 0.4902
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93      2069
#            1       0.86      0.49      0.63       512
#
#     accuracy                           0.88      2581
#    macro avg       0.87      0.74      0.78      2581
# weighted avg       0.88      0.88      0.87      2581

# %%
classifier(ds, "random_forest")
# Out:
# 0it [00:26, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 classifier(ds, "random_forest", "tfidf", 0.2, None)
#
# File ~/Code/Education/module-1/ai4se-hse-course-24-25/01-toxic-review-classification/toxic_clf/models.py:121, in classifier(dataset, model_type, vectorizer, test_size, checkpoint, random_state)
#     119     X_train_vec = vectorizer.fit_transform(X_train)
#     120     X_test_vec = vectorizer.transform(X_test)
# --> 121     train_classic_model(X_train_vec, y_train, X_test_vec, y_test, model_type)
#     122 elif model_type in ["roberta-base", "microsoft/codebert-base"]:
#     123     train_transformer_model(
#     124         X_train, y_train, X_test, y_test, model_type, checkpoint
#     125     )
#
# ...

# %%
classifier(ds, "roberta-base")

# %%
classifier(ds, "microsoft/codebert-base")
